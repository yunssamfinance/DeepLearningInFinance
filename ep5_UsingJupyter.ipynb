# %%
print("Hello world!")
# Out:
# Hello world!

# %% [markdown]
# # Big title
# ## Large title
# ### Medium title
# #### Small title

# %% [markdown]
# This is *italics*
# This is **bold**

# %% [markdown]
# - Chapter 1
# - Chapter 2
# - Chapter 3
#     - Section A
#     - Section B

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
plt.plot([1, 2, 3, 4])
plt.ylabel('some numbers')
plt.show()
